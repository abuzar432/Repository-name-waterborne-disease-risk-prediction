# %%
import pandas as pd
import numpy as np
df=pd.read_csv(r"C:\Users\Mohammed Abuzar\OneDrive\Pictures\Documents\AIML datasets\archive (5)\2017_lake_data.csv")
df.head()
# Out:
#    STN Code                        Name of Monitoring Location  \
# 0      1790                    PULICATE LAKE , NELLORE \nDIST.
# 1      2353  KONDACHARLA-AAVA LAKE, \nPARAWADA PHARMA CITY,...
# 2      2205                     MER BEEL AT MADHABPUR, \nASSAM
# 3      2206                DALONI BEEL NEAR \nJOGIGHOPA, ASSAM
# 4      1263  ELANGABEEL SYSTEM POND \n(CONNECTED TO R. KOLA...
#
#   Type Water Body        State Name Min Temperature  Max Temperature  \
# 0            LAKE  ANDHRA \nPRADESH            27.0             28.0
# 1            LAKE  ANDHRA \nPRADESH            24.0             28.0
# 2            LAKE             ASSAM            20.0             27.0
# 3            LAKE             ASSAM            22.0             36.0
# 4            POND             ASSAM            22.0             34.0
#
#   Min Dissolved Oxygen Max Dissolved Oxygen  Min pH  Max pH  Min Conductivity  \
# 0                  5.1                  6.9     7.1     8.5            3270.0
# 1                  5.9                  6.8     6.9     8.4             597.0
# 2                  2.2                  7.2     5.7     7.0              50.0
# 3                  5.1                  6.0     6.6     7.8              54.0
# 4                  0.7                  4.6     6.8     8.4             263.0
#
#    Max Conductivity  Min BOD  Max BOD  Min Nitrate N + Nitrite N  \
# 0          156600.0      1.0      2.3                       0.65
# 1            1034.0      1.3      2.3                       1.16
# 2             128.0      1.0     16.2                       0.10
# 3             153.0      0.9      2.8                       0.10
# 4             972.0      4.5     14.7                       0.80
#
#    Max Nitrate N + Nitrite N  Min Fecal Coliform  Max Fecal Coliform  \
# 0                       6.90                 2.0                 2.0
# 1                       3.36                11.0                29.0
# 2                       1.70               300.0              2000.0
# 3                       1.40               300.0              1200.0
# 4                       5.70              1100.0              3500.0
#
#    Min Total Coliform  Max Total Coliform
# 0               800.0              1600.0
# 1               350.0              2400.0
# 2               360.0              6400.0
# 3               300.0              5300.0
# 4               730.0             21000.0

# %%
df.columns
# Out:
# Index(['STN Code', 'Name of Monitoring Location', 'Type Water Body',
#        'State Name', 'Min Temperature', 'Max Temperature',
#        'Min Dissolved Oxygen', 'Max Dissolved Oxygen', 'Min pH', 'Max pH',
#        'Min Conductivity', 'Max Conductivity', 'Min BOD', 'Max BOD',
#        'Min Nitrate N + Nitrite N', 'Max Nitrate N + Nitrite N',
#        'Min Fecal Coliform', 'Max Fecal Coliform', 'Min Total Coliform',
#        'Max Total Coliform'],
#       dtype='object')

# %%
print(df.columns)
# Out:
# Index(['Type Water Body', 'State Name', 'Min Temperature',
#        'Min Dissolved Oxygen', 'Min pH', 'Min Conductivity', 'Min BOD',
#        'Min Nitrate N + Nitrite N', 'Min Fecal Coliform',
#        'Min Total Coliform'],
#       dtype='object')

# %%
# Drop unnecessary columns
df.drop([
    'STN Code',
    'Name of Monitoring Location',
    'Max Temperature',
    'Max Dissolved Oxygen',
    'Max pH',
    'Max Conductivity',
    'Max BOD',
    'Max Nitrate N + Nitrite N',
    'Max Fecal Coliform',
    'Max Total Coliform'
], axis=1, inplace=True)

# View cleaned data
df.head()
# Out:
#   Type Water Body        State Name Min Temperature Min Dissolved Oxygen  \
# 0            LAKE  ANDHRA \nPRADESH            27.0                  5.1
# 1            LAKE  ANDHRA \nPRADESH            24.0                  5.9
# 2            LAKE             ASSAM            20.0                  2.2
# 3            LAKE             ASSAM            22.0                  5.1
# 4            POND             ASSAM            22.0                  0.7
#
#    Min pH  Min Conductivity  Min BOD  Min Nitrate N + Nitrite N  \
# 0     7.1            3270.0      1.0                       0.65
# 1     6.9             597.0      1.3                       1.16
# 2     5.7              50.0      1.0                       0.10
# 3     6.6              54.0      0.9                       0.10
# 4     6.8             263.0      4.5                       0.80
#
#    Min Fecal Coliform  Min Total Coliform
# 0                 2.0               800.0
# 1                11.0               350.0
# 2               300.0               360.0
# 3               300.0               300.0
# 4              1100.0               730.0

# %%
df.isnull().sum()
# Out:
# Type Water Body               0
# State Name                    0
# Min Temperature               4
# Min Dissolved Oxygen          1
# Min pH                        1
# Min Conductivity              4
# Min BOD                       6
# Min Nitrate N + Nitrite N    21
# Min Fecal Coliform           54
# Min Total Coliform           34
# dtype: int64

# %%
numeric_cols = df.select_dtypes(include=np.number).columns
categorical_cols = df.select_dtypes(exclude=np.number).columns
print(numeric_cols)
print(categorical_cols)
# Out:
# Index(['Min pH', 'Min Conductivity', 'Min BOD', 'Min Nitrate N + Nitrite N',
#        'Min Fecal Coliform', 'Min Total Coliform'],
#       dtype='object')
# Index(['Type Water Body', 'State Name', 'Min Temperature',
#        'Min Dissolved Oxygen'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Type Water Body               object
# State Name                    object
# Min Temperature               object
# Min Dissolved Oxygen          object
# Min pH                       float64
# Min Conductivity             float64
# Min BOD                      float64
# Min Nitrate N + Nitrite N    float64
# Min Fecal Coliform           float64
# Min Total Coliform           float64
# dtype: object

# %%
for col in numeric_cols:
    if df[col].isnull().sum() > 0:
        df[col] = df[col].fillna(df[col].median())

# %%
for col in categorical_cols:
    if df[col].isnull().sum() > 0:
        df[col] = df[col].fillna(df[col].mode()[0])

# %%
df.isnull().sum()
# Out:
# Type Water Body              0
# State Name                   0
# Min Temperature              0
# Min Dissolved Oxygen         0
# Min pH                       0
# Min Conductivity             0
# Min BOD                      0
# Min Nitrate N + Nitrite N    0
# Min Fecal Coliform           0
# Min Total Coliform           0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
from sklearn.impute import SimpleImputer
mean_imputer = SimpleImputer(strategy="mean")
df[numeric_cols] = mean_imputer.fit_transform(df[numeric_cols])

# %%
cat_imputer = SimpleImputer(strategy="most_frequent")
df[categorical_cols] = cat_imputer.fit_transform(df[categorical_cols])

# %%
df.isnull().sum()
# Out:
# Type Water Body              0
# State Name                   0
# Min Temperature              0
# Min Dissolved Oxygen         0
# Min pH                       0
# Min Conductivity             0
# Min BOD                      0
# Min Nitrate N + Nitrite N    0
# Min Fecal Coliform           0
# Min Total Coliform           0
# dtype: int64

# %%
duplicate_count = df.duplicated().sum()
print(duplicate_count)
# Out:
# 0

# %%
for col in numeric_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1- 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
outliers
# Out:
#     Type Water Body     State Name Min Temperature Min Dissolved Oxygen  \
# 31             LAKE          BIHAR            19.0                  5.4
# 33             POND          BIHAR            18.0                  6.2
# 44             LAKE            GOA            26.0                  0.0
# 101            LAKE      KARNATAKA            21.0                  2.8
# 102            LAKE      KARNATAKA            24.0                  5.2
# ..              ...            ...             ...                  ...
# 360            POND  UTTAR PRADESH            16.0                  0.0
# 364            LAKE    WEST BENGAL            21.0                  4.1
# 365            LAKE    WEST BENGAL            21.0                  3.9
# 366            LAKE    WEST BENGAL            21.0                  5.3
# 368            LAKE    WEST BENGAL            10.0                  6.4
#
#      Min pH  Min Conductivity  Min BOD  Min Nitrate N + Nitrite N  \
# 31      7.2             222.0      2.1                        0.0
# 33      7.1             340.0      2.6                        0.0
# 44      6.4             289.0      1.1                        0.0
# 101     6.4            1203.0      6.5                        0.1
# 102     7.4             526.0      4.0                        0.2
# ..      ...               ...      ...                        ...
# 360     7.1             877.0     85.0                        0.0
# 364     7.6             618.0      5.3                        0.0
# 365     7.5             629.0      4.0                        0.0
# 366     7.8             615.0      1.9                        0.0
# 368     6.7              64.0      2.3                        0.3
#
#      Min Fecal Coliform  Min Total Coliform
# 31               7000.0             15000.0
# 33               1700.0              3900.0
# 44              35000.0             54000.0
# 101              1100.0              4700.0
# 102               920.0              4600.0
# ..                  ...                 ...
# 360              1200.0             28000.0
# 364             70000.0             90000.0
# 365             80000.0            110000.0
# 366             80000.0            110000.0
# 368              2700.0              9000.0
#
# [61 rows x 10 columns]

# %%
outliers.index
# Out:
# Index([ 31,  33,  44, 101, 102, 103, 104, 105, 106, 108, 110, 111, 112, 113,
#        114, 115, 116, 117, 118, 119, 120, 121, 124, 125, 126, 127, 129, 130,
#        131, 137, 138, 140, 142, 143, 144, 146, 147, 148, 150, 151, 152, 154,
#        155, 156, 157, 158, 159, 162, 163, 164, 165, 188, 191, 357, 358, 359,
#        360, 364, 365, 366, 368],
#       dtype='int64')

# %%
df.drop(outliers.index,axis=0,inplace=True)

# %%
df.to_csv(r"C:\AIML waterbourne project\Lake dataset.csv", index=False)
