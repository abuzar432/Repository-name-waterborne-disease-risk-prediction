# %%
import pandas as pd
import numpy as np
df=pd.read_csv(r"C:\Users\Mohammed Abuzar\OneDrive\Pictures\Documents\AIML datasets\archive (5)\2019_lake_data.csv")
df.head()
# Out:
#    STN Code                        Name of Monitoring Location  \
# 0      1790                       PULICATE LAKE , NELLORE DIST
# 1      2353  KONDAKARLA-AAVA LAKE, PARAWADA \nPHARMA CITY, ...
# 2      4368    KOLLERU LAKE KOKKIRAYALANKA (V), \nKAILALUR (M)
# 3      4391     CHENGAMBAKAM TANK IN SRI CITY SEZ, \nTIRUPATHI
# 4      1529                                 DEEPAR BEEL, ASSAM
#
#   Type Water Body        State Name  Min Temperature  Max Temperature  \
# 0            LAKE  ANDHRA \nPRADESH             18.0             28.0
# 1            LAKE  ANDHRA \nPRADESH             24.0             30.0
# 2            LAKE  ANDHRA \nPRADESH             25.0             28.0
# 3            TANK  ANDHRA \nPRADESH             25.0             36.0
# 4            LAKE             ASSAM             22.0             34.0
#
#   Min Dissolved Oxygen Max Dissolved Oxygen  Min pH  Max pH  Min Conductivity  \
# 0                  4.9                  5.5     6.7     8.2           21840.0
# 1                  5.0                  6.8     7.0     8.5             714.0
# 2                  3.7                  7.5     7.2     8.1             979.0
# 3                  3.2                  6.1     6.8     7.9             228.0
# 4                  4.6                 11.0     7.1     8.0             144.0
#
#    Max Conductivity Min BOD Max BOD Min Nitrate N + Nitrite N  \
# 0           47890.0    2.20    2.80                      0.46
# 1            1950.0    1.60    4.20                      0.00
# 2           14730.0    1.70    5.40                      0.00
# 3            1098.0    2.00   22.00                      0.00
# 4             273.0    2.70    4.80                      1.10
#
#    Max Nitrate N + Nitrite N Min Fecal Coliform  Max Fecal Coliform  \
# 0                       2.80                  3                 4.0
# 1                       5.82                 11                23.0
# 2                       3.47                  4                20.0
# 3                       4.40                100               200.0
# 4                       2.00                  2               360.0
#
#   Min Total Coliform Max Total Coliform
# 0                210               1600
# 1                150               1100
# 2                150               1300
# 3                400               1400
# 4                360               1500

# %%
df.columns
# Out:
# Index(['STN Code', 'Name of Monitoring Location', 'Type Water Body',
#        'State Name', 'Min Temperature', 'Max Temperature',
#        'Min Dissolved Oxygen', 'Max Dissolved Oxygen', 'Min pH', 'Max pH',
#        'Min Conductivity', 'Max Conductivity', 'Min BOD', 'Max BOD',
#        'Min Nitrate N + Nitrite N', 'Max Nitrate N + Nitrite N',
#        'Min Fecal Coliform', 'Max Fecal Coliform', 'Min Total Coliform',
#        'Max Total Coliform'],
#       dtype='object')

# %%
# Drop unnecessary columns
df.drop([
    'STN Code',
    'Name of Monitoring Location',
    'Max Temperature',
    'Max Dissolved Oxygen',
    'Max pH',
    'Max Conductivity',
    'Max BOD',
    'Max Nitrate N + Nitrite N',
    'Max Fecal Coliform',
    'Max Total Coliform'
], axis=1, inplace=True)

# View cleaned data
df.head()
# Out:
#   Type Water Body        State Name  Min Temperature Min Dissolved Oxygen  \
# 0            LAKE  ANDHRA \nPRADESH             18.0                  4.9
# 1            LAKE  ANDHRA \nPRADESH             24.0                  5.0
# 2            LAKE  ANDHRA \nPRADESH             25.0                  3.7
# 3            TANK  ANDHRA \nPRADESH             25.0                  3.2
# 4            LAKE             ASSAM             22.0                  4.6
#
#    Min pH  Min Conductivity Min BOD Min Nitrate N + Nitrite N  \
# 0     6.7           21840.0    2.20                      0.46
# 1     7.0             714.0    1.60                      0.00
# 2     7.2             979.0    1.70                      0.00
# 3     6.8             228.0    2.00                      0.00
# 4     7.1             144.0    2.70                      1.10
#
#   Min Fecal Coliform Min Total Coliform
# 0                  3                210
# 1                 11                150
# 2                  4                150
# 3                100                400
# 4                  2                360

# %%
print(df.columns)
# Out:
# Index(['Type Water Body', 'State Name', 'Min Temperature',
#        'Min Dissolved Oxygen', 'Min pH', 'Min Conductivity', 'Min BOD',
#        'Min Nitrate N + Nitrite N', 'Min Fecal Coliform',
#        'Min Total Coliform'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Type Water Body               0
# State Name                    0
# Min Temperature               3
# Min Dissolved Oxygen          4
# Min pH                        2
# Min Conductivity              6
# Min BOD                       3
# Min Nitrate N + Nitrite N    36
# Min Fecal Coliform           51
# Min Total Coliform           51
# dtype: int64

# %%
numeric_cols = df.select_dtypes(include=np.number).columns
categorical_cols = df.select_dtypes(exclude=np.number).columns
print(numeric_cols)
print(categorical_cols)
# Out:
# Index(['Min Temperature', 'Min pH', 'Min Conductivity'], dtype='object')
# Index(['Type Water Body', 'State Name', 'Min Dissolved Oxygen', 'Min BOD',
#        'Min Nitrate N + Nitrite N', 'Min Fecal Coliform',
#        'Min Total Coliform'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Type Water Body               object
# State Name                    object
# Min Temperature              float64
# Min Dissolved Oxygen          object
# Min pH                       float64
# Min Conductivity             float64
# Min BOD                       object
# Min Nitrate N + Nitrite N     object
# Min Fecal Coliform            object
# Min Total Coliform            object
# dtype: object

# %%
for col in numeric_cols:
    if df[col].isnull().sum() > 0:
        df[col] = df[col].fillna(df[col].median())

# %%
for col in categorical_cols:
    if df[col].isnull().sum() > 0:
        df[col] = df[col].fillna(df[col].mode()[0])

# %%
df.isnull().sum()
# Out:
# Type Water Body              0
# State Name                   0
# Min Temperature              0
# Min Dissolved Oxygen         0
# Min pH                       0
# Min Conductivity             0
# Min BOD                      0
# Min Nitrate N + Nitrite N    0
# Min Fecal Coliform           0
# Min Total Coliform           0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
from sklearn.impute import SimpleImputer
mean_imputer = SimpleImputer(strategy="mean")
df[numeric_cols] = mean_imputer.fit_transform(df[numeric_cols])

# %%
cat_imputer = SimpleImputer(strategy="most_frequent")
df[categorical_cols] = cat_imputer.fit_transform(df[categorical_cols])

# %%
df.isnull().sum()
# Out:
# Type Water Body              0
# State Name                   0
# Min Temperature              0
# Min Dissolved Oxygen         0
# Min pH                       0
# Min Conductivity             0
# Min BOD                      0
# Min Nitrate N + Nitrite N    0
# Min Fecal Coliform           0
# Min Total Coliform           0
# dtype: int64

# %%
duplicate_count = df.duplicated().sum()
print(duplicate_count)
# Out:
# 0

# %%
for col in numeric_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1- 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
outliers
# Out:
#     Type Water Body        State Name  Min Temperature Min Dissolved Oxygen  \
# 0              LAKE  ANDHRA \nPRADESH             18.0                  4.9
# 47             LAKE             DELHI              8.0                  2.8
# 59             LAKE           GUJARAT             25.0                  6.0
# 74             LAKE           GUJARAT             26.0                  2.8
# 75             LAKE           GUJARAT             26.0                  3.3
# 153            LAKE         KARNATAKA             22.0                  BDL
# 256            TANK         KARNATAKA             26.0                  5.4
# 268            LAKE            KERALA             19.0                  3.4
# 269            LAKE            KERALA             19.0                  5.4
# 273            LAKE            KERALA             26.0                  1.1
# 353            LAKE            ODISHA             20.0                  6.4
# 355            LAKE            ODISHA             13.0                  6.2
# 389            LAKE         RAJASTHAN             15.0                  0.5
# 399            LAKE        TAMIL NADU             24.0                  3.1
# 406            LAKE         TELANGANA             26.0                  0.0
# 417            LAKE         TELANGANA             23.0                  0.0
# 419            LAKE         TELANGANA             28.0                  0.1
# 440            LAKE         TELANGANA             27.0                  1.2
# 445            LAKE         TELANGANA             27.0                  0.1
# 447            LAKE         TELANGANA             22.0                  0.0
# 450            POND         TELANGANA             26.0                  0.0
# 452            POND         TELANGANA             21.0                  0.0
# 456            POND         TELANGANA             26.0                  0.0
# 463            TANK         TELANGANA             18.0                  1.3
# 464            TANK         TELANGANA             21.0                  5.5
# 465            TANK         TELANGANA             23.0                  0.0
# 466            TANK         TELANGANA             21.0                  5.1
# 467            TANK         TELANGANA             26.0                  0.0
# 474            TANK         TELANGANA             28.0                  0.0
# 478            TANK         TELANGANA             21.0                  4.5
# 484            TANK         TELANGANA             23.0                  4.6
# 486            TANK         TELANGANA             23.0                  4.9
#
#      Min pH  Min Conductivity Min BOD Min Nitrate N + Nitrite N  \
# 0       6.7           21840.0    2.20                      0.46
# 47      8.1            6500.0   27.00                      0.31
# 59      8.1            2408.0   11.00                      0.06
# 74      8.4            6419.0   14.00                      0.00
# 75      8.3            2892.0    9.00                      0.00
# 153     7.1            2200.0   13.00                      1.10
# 256     9.1            3170.0    9.00                      0.10
# 268     7.5           18120.0    1.40                      0.98
# 269     7.4           12260.0    1.40                      0.79
# 273     7.5            6458.0    0.50                      0.03
# 353     6.6            1606.0    0.80                      0.20
# 355     7.4            9842.0    1.20                      0.13
# 389     7.9            2500.0    5.00                      2.21
# 399     6.1           24200.0    2.00                      0.00
# 406     7.2            2132.0   36.00                      4.58
# 417     6.9            1720.0   32.00                      1.00
# 419     7.0            1783.0   24.00                     12.00
# 440     7.0            2200.0   50.00                     51.87
# 445     7.1            1660.0   24.00                     16.00
# 447     7.2            1510.0   22.00                      0.98
# 450     7.0            6570.0  122.00                      8.00
# 452     6.5            3064.0   77.00                      7.75
# 456     7.0            1520.0   24.00                      3.72
# 463     6.8            1840.0    2.00                     12.37
# 464     6.4            2441.0    3.40                      9.28
# 465     6.9            3072.0   26.00                     10.00
# 466     6.7            2021.0    2.40                     15.30
# 467     7.1            1524.0   24.00                      2.60
# 474     7.2            1669.0   28.00                     15.10
# 478     6.5            4860.0    6.30                     20.62
# 484     6.5            3370.0    5.60                     21.40
# 486     7.3            1598.0    3.40                     10.37
#
#     Min Fecal Coliform Min Total Coliform
# 0                    3                210
# 47               17000              22000
# 59                  12                120
# 74                  12                 70
# 75                   2                  2
# 153                940               5400
# 256                  2                BDL
# 268                260                480
# 269                100                220
# 273                  2                 20
# 353                 20                 78
# 355                  2                BDL
# 389                 39                120
# 399                  2                BDL
# 406                 20                350
# 417                 20                330
# 419                  2                BDL
# 440                  2                300
# 445                  2                BDL
# 447                 22                350
# 450                 22                350
# 452                  2                BDL
# 456                 19                290
# 463                  2                BDL
# 464                  2                BDL
# 465                 14                350
# 466                  2                BDL
# 467                 20                350
# 474                 46                350
# 478                  2                BDL
# 484                  2                BDL
# 486                  2                BDL

# %%
outliers.index
# Out:
# Index([  0,  47,  59,  74,  75, 153, 256, 268, 269, 273, 353, 355, 389, 399,
#        406, 417, 419, 440, 445, 447, 450, 452, 456, 463, 464, 465, 466, 467,
#        474, 478, 484, 486],
#       dtype='int64')

# %%
df.drop(outliers.index,axis=0,inplace=True)

# %%
df.to_csv(r"C:\AIML waterbourne project\Lake dataset.csv", index=False)
